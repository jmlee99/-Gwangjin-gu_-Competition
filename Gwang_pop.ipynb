# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.api as sm

# %%
filename = '인구밀도_20230327001327.csv'
np_data = pd.read_csv(filename, encoding = 'UTF-8').to_numpy()

header_data = np_data[1, 2:]
yr_data = np_data[2:,1]


np_data = np_data[2:, 2:].astype(np.int64)
print(header_data)
print(np_data, np_data.shape)
print(yr_data)
# Out:
# ['화양동' '군자동' '중곡1동' '중곡2동' '중곡3동' '중곡4동' '능동' '구의1동' '구의2동' '구의3동' '광장동'
#  '자양1동' '자양2동' '자양3동' '자양4동']
# [[23990 22227 17244 23234 19106 32281 11328 23547 27744 30036 37100 26164
#   29114 32296 28858]
#  [24293 22136 17021 23156 18843 31966 11331 23226 27787 29808 37493 25374
#   28596 31929 28480]
#  [24269 22189 16648 22633 18475 31842 11470 23290 26479 29997 37159 24459
#   28520 31436 28509]
#  [24419 22091 16526 22610 18120 32041 11712 23510 25879 30067 36917 24151
#   27877 31227 28033]
#  [24495 22048 16342 22877 17960 31786 11648 23387 25889 29789 36613 23951
#   27532 30555 27232]
#  [24610 21980 16359 22808 17992 31618 11838 23396 25936 30483 36589 24450
#   27727 30517 25995]
#  [24804 22029 16500 22699 17843 31159 11891 23282 27974 30476 36309 24476
#   27435 30132 24054]
#  [25537 22109 16287 22564 17315 30516 11978 23063 27902 30094 36083 24156
#   26893 29475 23000]
#  [25541 21903 16190 22285 16902 29815 11913 22700 27444 29588 35619 23710
#   26016 28957 21526]
# ...

# %%
# 광진구 전체 년도별 총 인구 데이터
G_sum_2012 = np.sum(np_data[0, :])
G_sum_2013 = np.sum(np_data[1, :])
G_sum_2014 = np.sum(np_data[2, :])
G_sum_2015 = np.sum(np_data[3, :])
G_sum_2016 = np.sum(np_data[4, :])
G_sum_2017 = np.sum(np_data[5, :])
G_sum_2018 = np.sum(np_data[6, :])
G_sum_2019 = np.sum(np_data[7, :])
G_sum_2020 = np.sum(np_data[8, :])
G_sum_2021 = np.sum(np_data[9, :])
G_sum_2022 = np.sum(np_data[10, :])

G_total = np.array([G_sum_2012, G_sum_2013, G_sum_2014, G_sum_2015, G_sum_2016, G_sum_2017, G_sum_2018, G_sum_2019, G_sum_2020,
                   G_sum_2021, G_sum_2022])

print('광진구 연도별 인구 :', G_total)

x = np.arange(2012, 2023)
y = G_total
_, axe = plt.subplots()
axe.scatter(x, y)
axe.plot(x, y)

#화양동 인구변화 추세
G_sum_2012_Hwa = np_data[0, 0]
G_sum_2013_Hwa = np_data[1, 0]
G_sum_2014_Hwa = np_data[2, 0]
G_sum_2015_Hwa = np_data[3, 0]
G_sum_2016_Hwa = np_data[4, 0]
G_sum_2017_Hwa = np_data[5, 0]
G_sum_2018_Hwa = np_data[6, 0]
G_sum_2019_Hwa = np_data[7, 0]
G_sum_2020_Hwa = np_data[8, 0]
G_sum_2021_Hwa = np_data[9, 0]
G_sum_2022_Hwa = np_data[10, 0]

G_total_Hwa = np.array([G_sum_2012_Hwa, G_sum_2013_Hwa, G_sum_2014_Hwa, G_sum_2015_Hwa, G_sum_2016_Hwa,
                    G_sum_2017_Hwa, G_sum_2018_Hwa, G_sum_2019_Hwa, G_sum_2020_Hwa, G_sum_2021_Hwa, G_sum_2022_Hwa])

print('화양동 연도별 인구:', G_total_Hwa)

y1 = G_total_Hwa
_, axe = plt.subplots()
axe.scatter(x, y1, c = 'r')
axe.plot(x, y1, c = 'r')

#군자동 인구변화 추세
G_sum_2012_Gun = np_data[0, 1]
G_sum_2013_Gun = np_data[1, 1]
G_sum_2014_Gun = np_data[2, 1]
G_sum_2015_Gun = np_data[3, 1]
G_sum_2016_Gun = np_data[4, 1]
G_sum_2017_Gun = np_data[5, 1]
G_sum_2018_Gun = np_data[6, 1]
G_sum_2019_Gun = np_data[7, 1]
G_sum_2020_Gun = np_data[8, 1]
G_sum_2021_Gun = np_data[9, 1]
G_sum_2022_Gun = np_data[10, 1]

G_total_Gun = np.array([G_sum_2012_Gun, G_sum_2013_Gun, G_sum_2014_Gun, G_sum_2015_Gun, G_sum_2016_Gun,
                    G_sum_2017_Gun, G_sum_2018_Gun, G_sum_2019_Gun, G_sum_2020_Gun, G_sum_2021_Gun, G_sum_2022_Gun])

print('군자동 연도별 인구:', G_total_Gun)

y2 = G_total_Gun
_, axe = plt.subplots()
axe.scatter(x, y2, c = 'g')
axe.plot(x, y2, c = 'g')

#중곡1동 인구변화 추세
G_sum_2012_Jung1 = np_data[0, 2]
G_sum_2013_Jung1 = np_data[1, 2]
G_sum_2014_Jung1 = np_data[2, 2]
G_sum_2015_Jung1 = np_data[3, 2]
G_sum_2016_Jung1 = np_data[4, 2]
G_sum_2017_Jung1 = np_data[5, 2]
G_sum_2018_Jung1 = np_data[6, 2]
G_sum_2019_Jung1 = np_data[7, 2]
G_sum_2020_Jung1 = np_data[8, 2]
G_sum_2021_Jung1 = np_data[9, 2]
G_sum_2022_Jung1 = np_data[10, 2]

G_total_Jung1 = np.array([G_sum_2012_Jung1, G_sum_2013_Jung1, G_sum_2014_Jung1, G_sum_2015_Jung1, G_sum_2016_Jung1,
                    G_sum_2017_Jung1, G_sum_2018_Jung1, G_sum_2019_Jung1, G_sum_2020_Jung1, G_sum_2021_Jung1, G_sum_2022_Jung1])

print('중곡1동 연도별 인구:', G_total_Jung1)

y3 = G_total_Jung1
_, axe = plt.subplots()
axe.scatter(x, y3, c = 'b')
axe.plot(x, y3, c = 'b')

#중곡2동 인구변화 추세
G_sum_2012_Jung2 = np_data[0, 3]
G_sum_2013_Jung2 = np_data[1, 3]
G_sum_2014_Jung2 = np_data[2, 3]
G_sum_2015_Jung2 = np_data[3, 3]
G_sum_2016_Jung2 = np_data[4, 3]
G_sum_2017_Jung2 = np_data[5, 3]
G_sum_2018_Jung2 = np_data[6, 3]
G_sum_2019_Jung2 = np_data[7, 3]
G_sum_2020_Jung2 = np_data[8, 3]
G_sum_2021_Jung2 = np_data[9, 3]
G_sum_2022_Jung2 = np_data[10, 3]

G_total_Jung2 = np.array([G_sum_2012_Jung2, G_sum_2013_Jung2, G_sum_2014_Jung2, G_sum_2015_Jung2, G_sum_2016_Jung2,
                    G_sum_2017_Jung2, G_sum_2018_Jung2, G_sum_2019_Jung2, G_sum_2020_Jung2, G_sum_2021_Jung2, G_sum_2022_Jung2])

print('중곡2동 연도별 인구:', G_total_Jung2)

y4 = G_total_Jung2
_, axe = plt.subplots()
axe.scatter(x, y4, c = 'limegreen')
axe.plot(x, y4, c = 'limegreen')

#중곡3동 인구변화 추세
G_sum_2012_Jung3 = np_data[0, 4]
G_sum_2013_Jung3 = np_data[1, 4]
G_sum_2014_Jung3 = np_data[2, 4]
G_sum_2015_Jung3 = np_data[3, 4]
G_sum_2016_Jung3 = np_data[4, 4]
G_sum_2017_Jung3 = np_data[5, 4]
G_sum_2018_Jung3 = np_data[6, 4]
G_sum_2019_Jung3 = np_data[7, 4]
G_sum_2020_Jung3 = np_data[8, 4]
G_sum_2021_Jung3 = np_data[9, 4]
G_sum_2022_Jung3 = np_data[10, 4]

G_total_Jung3 = np.array([G_sum_2012_Jung3, G_sum_2013_Jung3, G_sum_2014_Jung3, G_sum_2015_Jung3, G_sum_2016_Jung3,
                    G_sum_2017_Jung3, G_sum_2018_Jung3, G_sum_2019_Jung3, G_sum_2020_Jung3, G_sum_2021_Jung3, G_sum_2022_Jung3])

print('중곡3동 연도별 인구:', G_total_Jung3)

y5 = G_total_Jung3
_, axe = plt.subplots()
axe.scatter(x, y5, c = 'pink')
axe.plot(x, y5, c = 'pink')
# Out:
# 광진구 연도별 인구 : [384269 381439 377375 375180 372104 372298 371063 366972 360109 352627
#  351252]
# 화양동 연도별 인구: [23990 24293 24269 24419 24495 24610 24804 25537 25541 26034 27082]
# 군자동 연도별 인구: [22227 22136 22189 22091 22048 21980 22029 22109 21903 21500 21524]
# 중곡1동 연도별 인구: [17244 17021 16648 16526 16342 16359 16500 16287 16190 15862 15663]
# 중곡2동 연도별 인구: [23234 23156 22633 22610 22877 22808 22699 22564 22285 21739 21336]
# 중곡3동 연도별 인구: [19106 18843 18475 18120 17960 17992 17843 17315 16902 16357 16177]

# %%
#중곡4동 인구변화 추세
G_sum_2012_Jung4 = np_data[0, 5]
G_sum_2013_Jung4 = np_data[1, 5]
G_sum_2014_Jung4 = np_data[2, 5]
G_sum_2015_Jung4 = np_data[3, 5]
G_sum_2016_Jung4 = np_data[4, 5]
G_sum_2017_Jung4 = np_data[5, 5]
G_sum_2018_Jung4 = np_data[6, 5]
G_sum_2019_Jung4 = np_data[7, 5]
G_sum_2020_Jung4 = np_data[8, 5]
G_sum_2021_Jung4 = np_data[9, 5]
G_sum_2022_Jung4 = np_data[10, 5]

G_total_Jung4 = np.array([G_sum_2012_Jung4, G_sum_2013_Jung4, G_sum_2014_Jung4, G_sum_2015_Jung4, G_sum_2016_Jung4,
                    G_sum_2017_Jung4, G_sum_2018_Jung4, G_sum_2019_Jung4, G_sum_2020_Jung4, G_sum_2021_Jung4, G_sum_2022_Jung4])

print('중곡4동 연도별 인구:', G_total_Jung4)

y6 = G_total_Jung4
_, axe = plt.subplots()
axe.scatter(x, y6, c = 'purple')
axe.plot(x, y6, c = 'purple')

#능동 인구변화 추세
G_sum_2012_Neung = np_data[0, 6]
G_sum_2013_Neung = np_data[1, 6]
G_sum_2014_Neung = np_data[2, 6]
G_sum_2015_Neung = np_data[3, 6]
G_sum_2016_Neung = np_data[4, 6]
G_sum_2017_Neung = np_data[5, 6]
G_sum_2018_Neung = np_data[6, 6]
G_sum_2019_Neung = np_data[7, 6]
G_sum_2020_Neung = np_data[8, 6]
G_sum_2021_Neung = np_data[9, 6]
G_sum_2022_Neung = np_data[10, 6]

G_total_Neung = np.array([G_sum_2012_Neung, G_sum_2013_Neung, G_sum_2014_Neung, G_sum_2015_Neung, G_sum_2016_Neung,
                    G_sum_2017_Neung, G_sum_2018_Neung, G_sum_2019_Neung, G_sum_2020_Neung, G_sum_2021_Neung, G_sum_2022_Neung])

print('능동 연도별 인구:', G_total_Neung)

y7 = G_total_Neung
_, axe = plt.subplots()
axe.scatter(x, y7, c = 'orange')
axe.plot(x, y7, c = 'orange')

#구의1동 인구변화 추세
G_sum_2012_Gu1 = np_data[0, 7]
G_sum_2013_Gu1 = np_data[1, 7]
G_sum_2014_Gu1 = np_data[2, 7]
G_sum_2015_Gu1 = np_data[3, 7]
G_sum_2016_Gu1 = np_data[4, 7]
G_sum_2017_Gu1 = np_data[5, 7]
G_sum_2018_Gu1 = np_data[6, 7]
G_sum_2019_Gu1 = np_data[7, 7]
G_sum_2020_Gu1 = np_data[8, 7]
G_sum_2021_Gu1 = np_data[9, 7]
G_sum_2022_Gu1 = np_data[10,7]

G_total_Gu1 = np.array([G_sum_2012_Gu1, G_sum_2013_Gu1, G_sum_2014_Gu1, G_sum_2015_Gu1, G_sum_2016_Gu1,
                    G_sum_2017_Gu1, G_sum_2018_Gu1, G_sum_2019_Gu1, G_sum_2020_Gu1, G_sum_2021_Gu1, G_sum_2022_Gu1])
print('구의1동 연도별 인구:', G_total_Gu1)

y8 = G_total_Gu1
_, axe = plt.subplots()
axe.scatter(x, y8, c = 'brown')
axe.plot(x, y8, c = 'brown')

#구의2동 인구변화 추세
G_sum_2012_Gu2 = np_data[0, 8]
G_sum_2013_Gu2 = np_data[1, 8]
G_sum_2014_Gu2 = np_data[2, 8]
G_sum_2015_Gu2 = np_data[3, 8]
G_sum_2016_Gu2 = np_data[4, 8]
G_sum_2017_Gu2 = np_data[5, 8]
G_sum_2018_Gu2 = np_data[6, 8]
G_sum_2019_Gu2 = np_data[7, 8]
G_sum_2020_Gu2 = np_data[8, 8]
G_sum_2021_Gu2 = np_data[9, 8]
G_sum_2022_Gu2 = np_data[10,8]

G_total_Gu2 = np.array([G_sum_2012_Gu2, G_sum_2013_Gu2, G_sum_2014_Gu2, G_sum_2015_Gu2, G_sum_2016_Gu2,
                    G_sum_2017_Gu2, G_sum_2018_Gu2, G_sum_2019_Gu2, G_sum_2020_Gu2, G_sum_2021_Gu2, G_sum_2022_Gu2])
print('구의2동 연도별 인구:', G_total_Gu2)

y9 = G_total_Gu2
_, axe = plt.subplots()
axe.scatter(x, y9, c = 'violet')
axe.plot(x, y9, c = 'violet')

#구의3동 인구변화 추세
G_sum_2012_Gu3 = np_data[0, 9]
G_sum_2013_Gu3 = np_data[1, 9]
G_sum_2014_Gu3 = np_data[2, 9]
G_sum_2015_Gu3 = np_data[3, 9]
G_sum_2016_Gu3 = np_data[4, 9]
G_sum_2017_Gu3 = np_data[5, 9]
G_sum_2018_Gu3 = np_data[6, 9]
G_sum_2019_Gu3 = np_data[7, 9]
G_sum_2020_Gu3 = np_data[8, 9]
G_sum_2021_Gu3 = np_data[9, 9]
G_sum_2022_Gu3 = np_data[10,9]

G_total_Gu3 = np.array([G_sum_2012_Gu3, G_sum_2013_Gu3, G_sum_2014_Gu3, G_sum_2015_Gu3, G_sum_2016_Gu3,
                    G_sum_2017_Gu3, G_sum_2018_Gu3, G_sum_2019_Gu3, G_sum_2020_Gu3, G_sum_2021_Gu3, G_sum_2022_Gu3])
print('구의3동 연도별 인구:', G_total_Gu3)

y10 = G_total_Gu3
_, axe = plt.subplots()
axe.scatter(x, y10, c = 'darkblue')
axe.plot(x, y10, c = 'darkblue')

#광장동 인구변화 추세
G_sum_2012_Gwang = np_data[0, 10]
G_sum_2013_Gwang = np_data[1, 10]
G_sum_2014_Gwang = np_data[2, 10]
G_sum_2015_Gwang = np_data[3, 10]
G_sum_2016_Gwang = np_data[4, 10]
G_sum_2017_Gwang = np_data[5, 10]
G_sum_2018_Gwang = np_data[6, 10]
G_sum_2019_Gwang = np_data[7, 10]
G_sum_2020_Gwang = np_data[8, 10]
G_sum_2021_Gwang = np_data[9, 10]
G_sum_2022_Gwang = np_data[10,10]

G_total_Gwang = np.array([G_sum_2012_Gwang, G_sum_2013_Gwang, G_sum_2014_Gwang, G_sum_2015_Gwang, G_sum_2016_Gwang,
                    G_sum_2017_Gwang, G_sum_2018_Gwang, G_sum_2019_Gwang, G_sum_2020_Gwang, G_sum_2021_Gwang, G_sum_2022_Gwang])
print('광장동 연도별 인구:', G_total_Gwang)

y11 = G_total_Gwang
_, axe = plt.subplots()
axe.scatter(x, y11, c = 'aqua')
axe.plot(x, y11, c = 'aqua')
# Out:
# 중곡4동 연도별 인구: [32281 31966 31842 32041 31786 31618 31159 30516 29815 28954 28405]
# 능동 연도별 인구: [11328 11331 11470 11712 11648 11838 11891 11978 11913 11619 11561]
# 구의1동 연도별 인구: [23547 23226 23290 23510 23387 23396 23282 23063 22700 22139 24049]
# 구의2동 연도별 인구: [27744 27787 26479 25879 25889 25936 27974 27902 27444 27008 26573]
# 구의3동 연도별 인구: [30036 29808 29997 30067 29789 30483 30476 30094 29588 28891 28440]
# 광장동 연도별 인구: [37100 37493 37159 36917 36613 36589 36309 36083 35619 34834 34362]

# %%
#자양1동 인구변화 추세
G_sum_2012_Ja1 = np_data[0, 11]
G_sum_2013_Ja1 = np_data[1, 11]
G_sum_2014_Ja1 = np_data[2, 11]
G_sum_2015_Ja1 = np_data[3, 11]
G_sum_2016_Ja1 = np_data[4, 11]
G_sum_2017_Ja1 = np_data[5, 11]
G_sum_2018_Ja1 = np_data[6, 11]
G_sum_2019_Ja1 = np_data[7, 11]
G_sum_2020_Ja1 = np_data[8, 11]
G_sum_2021_Ja1 = np_data[9, 11]
G_sum_2022_Ja1 = np_data[10,11]

G_total_Ja1 = np.array([G_sum_2012_Ja1, G_sum_2013_Ja1, G_sum_2014_Ja1, G_sum_2015_Ja1, G_sum_2016_Ja1,
                    G_sum_2017_Ja1, G_sum_2018_Ja1, G_sum_2019_Ja1, G_sum_2020_Ja1, G_sum_2021_Ja1, G_sum_2022_Ja1])
print('자양1동 연도별 인구:', G_total_Ja1)

y12 = G_total_Ja1
_, axe = plt.subplots()
axe.scatter(x, y12, c = 'y')
axe.plot(x, y12, c = 'y')

#자양2동 인구변화 추세
G_sum_2012_Ja2 = np_data[0, 12]
G_sum_2013_Ja2 = np_data[1, 12]
G_sum_2014_Ja2 = np_data[2, 12]
G_sum_2015_Ja2 = np_data[3, 12]
G_sum_2016_Ja2 = np_data[4, 12]
G_sum_2017_Ja2 = np_data[5, 12]
G_sum_2018_Ja2 = np_data[6, 12]
G_sum_2019_Ja2 = np_data[7, 12]
G_sum_2020_Ja2 = np_data[8, 12]
G_sum_2021_Ja2 = np_data[9, 12]
G_sum_2022_Ja2 = np_data[10,12]

G_total_Ja2 = np.array([G_sum_2012_Ja2, G_sum_2013_Ja2, G_sum_2014_Ja2, G_sum_2015_Ja2, G_sum_2016_Ja2,
                    G_sum_2017_Ja2, G_sum_2018_Ja2, G_sum_2019_Ja2, G_sum_2020_Ja2, G_sum_2021_Ja2, G_sum_2022_Ja2])
print('자양2동 연도별 인구:', G_total_Ja2)

y13 = G_total_Ja2
_, axe = plt.subplots()
axe.scatter(x, y13, c = 'tan')
axe.plot(x, y13, c = 'tan')

#자양3동 인구변화 추세
G_sum_2012_Ja3 = np_data[0, 13]
G_sum_2013_Ja3 = np_data[1, 13]
G_sum_2014_Ja3 = np_data[2, 13]
G_sum_2015_Ja3 = np_data[3, 13]
G_sum_2016_Ja3 = np_data[4, 13]
G_sum_2017_Ja3 = np_data[5, 13]
G_sum_2018_Ja3 = np_data[6, 13]
G_sum_2019_Ja3 = np_data[7, 13]
G_sum_2020_Ja3 = np_data[8, 13]
G_sum_2021_Ja3 = np_data[9, 13]
G_sum_2022_Ja3 = np_data[10,13]

G_total_Ja3 = np.array([G_sum_2012_Ja3, G_sum_2013_Ja3, G_sum_2014_Ja3, G_sum_2015_Ja3, G_sum_2016_Ja3,
                    G_sum_2017_Ja3, G_sum_2018_Ja3, G_sum_2019_Ja3, G_sum_2020_Ja3, G_sum_2021_Ja3, G_sum_2022_Ja3])
print('자양3동 연도별 인구:', G_total_Ja3)

y14 = G_total_Ja3
_, axe = plt.subplots()
axe.scatter(x, y14, c = 'm')
axe.plot(x, y14, c = 'm')

#자양4동 인구변화 추세
G_sum_2012_Ja4 = np_data[0, 14]
G_sum_2013_Ja4 = np_data[1, 14]
G_sum_2014_Ja4 = np_data[2, 14]
G_sum_2015_Ja4 = np_data[3, 14]
G_sum_2016_Ja4 = np_data[4, 14]
G_sum_2017_Ja4 = np_data[5, 14]
G_sum_2018_Ja4 = np_data[6, 14]
G_sum_2019_Ja4 = np_data[7, 14]
G_sum_2020_Ja4 = np_data[8, 14]
G_sum_2021_Ja4 = np_data[9, 14]
G_sum_2022_Ja4 = np_data[10,14]

G_total_Ja4 = np.array([G_sum_2012_Ja4, G_sum_2013_Ja4, G_sum_2014_Ja4, G_sum_2015_Ja4, G_sum_2016_Ja4,
                    G_sum_2017_Ja4, G_sum_2018_Ja4, G_sum_2019_Ja4, G_sum_2020_Ja4, G_sum_2021_Ja4, G_sum_2022_Ja4])
print('자양4동 연도별 인구:', G_total_Ja4)

y15 = G_total_Ja4
_, axe = plt.subplots()
axe.scatter(x, y15, c = 'salmon')
axe.plot(x, y15, c = 'salmon')
# Out:
# 자양1동 연도별 인구: [26164 25374 24459 24151 23951 24450 24476 24156 23710 23134 22709]
# 자양2동 연도별 인구: [29114 28596 28520 27877 27532 27727 27435 26893 26016 24930 24253]
# 자양3동 연도별 인구: [32296 31929 31436 31227 30555 30517 30132 29475 28957 28330 27858]
# 자양4동 연도별 인구: [28858 28480 28509 28033 27232 25995 24054 23000 21526 21296 21260]

# %%
plt.figure(figsize=(20,22))

plt.scatter(x, y1, c = 'r')
plt.plot(x, y1, label = 'Hwayang-dong', c = 'r')

plt.scatter(x, y2, c = 'g')
plt.plot(x, y2,label = 'Gunja-dong', c = 'g')

plt.scatter(x, y3, c = 'b')
plt.plot(x, y3, label = 'Junggok-1dong', c = 'b')

plt.scatter(x, y4, c = 'limegreen')
plt.plot(x, y4, label = 'Junggok-2dong', c = 'limegreen')

plt.scatter(x, y5, c = 'pink')
plt.plot(x, y5, label = 'Junggok-3dong', c = 'pink')

plt.scatter(x, y6, c = 'purple')
plt.plot(x, y6, label = 'Junggok-4dong', c = 'purple')

plt.scatter(x, y7, c = 'orange')
plt.plot(x, y7, label = 'Neung-dong', c = 'orange')

plt.scatter(x, y8, c = 'brown')
plt.plot(x, y8, label = 'Guui-1dong', c = 'brown')

plt.scatter(x, y9, c = 'violet')
plt.plot(x, y9, label = 'Guui-2dong', c = 'violet')

plt.scatter(x, y10, c = 'darkblue')
plt.plot(x, y10, label = 'Guui-3dong', c = 'darkblue')

plt.scatter(x, y11, c = 'aqua')
plt.plot(x, y11, label = 'Gwangjang-dong', c = 'aqua')

plt.scatter(x, y12, c = 'y')
plt.plot(x, y12, label = 'Jayang-1dong', c = 'y')

plt.scatter(x, y13, c = 'tan')
plt.plot(x, y13, label = 'Jayang-2dong', c = 'tan')

plt.scatter(x, y14, c = 'm')
plt.plot(x, y14, label = 'Jayang-3dong', c = 'm')

plt.scatter(x, y15, c = 'salmon')
plt.plot(x, y15, label = 'Jayang-4dong', c = 'salmon')

plt.legend(loc = 'upper right', mode = "expand", ncol = 5, fontsize=10)

plt.xticks(x)
# Out:
# ([<matplotlib.axis.XTick at 0x7fc2580add80>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
file = '서울특별시 광진구_주정차단속현황_2015_22.csv'
pd_data = pd.read_csv(file, encoding = 'cp949')
print(pd_data.head())
# Out:
#               단속일시   단속원금  단속동         단속장소         위반내용  견인지시     데이터기준일자
# 0  2015-01-01 6:44  40000  화양동        119-4        주정차금지  견인처리  2022-06-10
# 1  2015-01-01 7:01  40000  화양동    건대입구1번출구앞  32조내지 34조위반   미견인  2022-06-10
# 2  2015-01-01 7:24  50000  구의동  동서울터미널 주차장앞  32조내지 34조위반   미견인  2022-06-10
# 3  2015-01-01 8:00  40000  화양동    건대입구1번출구앞  32조내지 34조위반   미견인  2022-06-10
# 4  2015-01-01 8:15  40000  화양동    건대입구1번출구앞  32조내지 34조위반   미견인  2022-06-10

# %%
df1 = pd_data['단속동']
print(df1)
# Out:
# 0         화양동
# 1         화양동
# 2         구의동
# 3         화양동
# 4         화양동
#          ...
# 473069    구의동
# 473070    구의동
# 473071    구의동
# 473072    광장동
# 473073    군자동
# Name: 단속동, Length: 473074, dtype: object

# %%
cnt = df1.value_counts()
print(cnt)


for i, n in enumerate(cnt.index):
    print(i, n)
# Out:
# 구의동        112344
# 자양동         89075
# 중곡동         76503
# 화양동         49480
# 광장동         42736
#             ...
# 동일로56다길         1
# 구의강변로7길         1
# 능동로47길          1
# 성내천로23길         1
# 노유동             1
# Name: 단속동, Length: 491, dtype: int64
# 0 구의동
# 1 자양동
# 2 중곡동
# 3 화양동
# 4 광장동
# 5 군자동
# 6 능동
# 7 아차산로
# 8 능동로
# 9 능  동
# 10 광나루로
# 11 영화사로
# 12 자양로
# 13 자양번영로
# 14 군자로
# 15 동일로18길
# 16 용마산로
# 17 광나루로56길
# 18 뚝섬로
# 19 긴고랑로
# 20 면목로
# 21 구의강변로
# 22 아차산로76길
# 23 천호대로
# 24 아차산로70길
# 25 광나루로52길
# 26 능동로19길
# 27 아차산로78길
# 28 자양로13길
# 29 동일로
# 30 광장로
# 31 자양강변길
# 32 워커힐로
# 33 뚝섬로31길
# 34 아차산로69길
# 35 아차산로34길
# 36 자양로18길
# 37 영화사로20길
# 38 능동로4길
# 39 뚝섬로41길
# 40 뚝섬로52길
# 41 뚝섬로46길
# 42 자양로19길
# 43 광나루로30길
# 44 자양로50길
# 45 동일로30길
# 46 구의로
# 47 강변역로4길
# 48 아차산로27길
# 49 뚝섬로24길
# 50 천호대로138길
# 51 자양로38길
# 52 영화사로16길
# 53 동일로52길
# 54 자양로37길
# 55 광장로1길
# 56 능동로24길
# 57 능동로13길
# 58 아차산로75길
# 59 광나루로46길
# 60 동일로22길
# 61 뚝섬로33길
# 62 구천면로
# 63 군자로15길
# 64 뚝섬로56가길
# 65 천호대로111길
# ...

# %%
df1 = cnt[:6]
print(df1)
# Out:
# 구의동    112344
# 자양동     89075
# 중곡동     76503
# 화양동     49480
# 광장동     42736
# 군자동     33716
# Name: 단속동, dtype: int64

# %%
Guui_dong = G_total_Gu1 + G_total_Gu2 + G_total_Gu3
print(Guui_dong) # 2012 ~ 2022
# Out:
# [81327 80821 79766 79456 79065 79815 81732 81059 79732 78038 79062]
